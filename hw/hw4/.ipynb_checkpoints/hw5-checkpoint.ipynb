# %% [markdown]
# ## Part 1

# %% [markdown]
# ### A

# %% [markdown]
# Since we are calculating P(x,y) is a generative model

# %% [markdown]
# ### B

# %% [markdown]
# $$L(x_i| \lambda) = \prod_{i=1}^{n} \frac{\lambda^{x_i}e^{-\lambda}}{x_i!}$$
# $$l(x_i| \lambda) = \sum_{i=1}^{n} ln(\lambda) x_i -\lambda-ln(x_i!)$$
# $$ \frac{\partial l(x_i| \lambda)}{\partial \lambda} = \sum_{i=1}^{n} \frac{ x_i}{\lambda} -1$$
# $$  \hat{\lambda}= \sum_{i=1}^{n} \frac{ x_i}{n}$$

# %% [markdown]
# ### C

# %% [markdown]
# We know that since is we are applying a Naive Bayes model, we have that $P(x,y) = p(y)p(x/y)$, then we know that $p(y)=p_1^{n}p_0^{(N-n)}$ also we know that $p_0 =  1-p_1$. Then $p(y)=p_1^{n}(1-p_1)^{(N-n)}$ . We know for MLE estimation that $\hat{p}_1 = \frac{\sum number of cases c=1}{sum all of cases} $
#
#
#
# On the case of $p(x_i/y=c)$ ~ Poisson($\lambda_c,X_i|y=c)$, were c $\epsilon$ {1,0}. This means when we construct the likehood function we get:
#
# $$P(x/y )= \prod_{i=1}^{N} P(X_i|\lambda_c , Y=c) $$
#
# Then the joint distribution is:
#
# $$P(x,y )= p_1^{n}(1-p_1)^{(N-n)}\prod_{i=1}^{N} P(X_i|\lambda_c , Y=c) $$
#
# Then if we divide by the value of P(X), but we know that P(X) is not dependent in Y, meaning that not affect the optimization problem, then:
#
# $$P(Y/X )= \frac{p_1^{n}(1-p_1)^{(N-n)}\prod_{i=1}^{N} P(X_i|\lambda_c , Y=c)}{P(X)} $$
# $$P(Y/X ) \propto p_1^{n}(1-p_1)^{(N-n)}\prod_{i=1}^{N} P(X_i|\lambda_c , Y=c) $$

# %% [markdown]
# ### D

# %% [markdown]
# For solving for the boundery we need to solve the following equation:
#
# $$ P(y=1) \prod_{i=1}^{n_1} P(X_i|\hat{\lambda}_1 , Y=1) = P(y=0) \prod_{i=1}^{n_0} P(X_i|\hat{\lambda}_0 , Y=0)$$
# $$ y=f(x) =ln\left( \frac{P(y=1) \prod_{i=1}^{n_1} P(X_i|\hat{\lambda}_1 , Y=1)}{ P(y=0) \prod_{i=1}^{n_0} P(X_i|\hat{\lambda}_0 , Y=0)}\right) $$
#
# $$ ln\left( \frac{P(y=1)}{P(y=0) }\right) + ln\left( \frac{\prod_{i=1}^{n_1} P(X_i|\hat{\lambda_1} , Y=1)}{ \prod_{i=1}^{n_0} P(X_i|\hat{\lambda_0} , Y=0)}\right) $$
#
# $$ ln\left( \frac{\hat{p}_1}{1-\hat{p}_1 }\right) + ln\left( \frac{\prod_{i=1}^{n}\frac{\hat{\lambda}_1^{x_i}e^{-\hat{\lambda}_1}}{x_i!}}{ \prod_{i=1}^{n} \frac{\hat{\lambda}_0^{x_i}e^{-\hat{\lambda}_0}}{x_i!}}\right) $$
#
# $$ ln\left( \frac{\hat{p}_1}{1-\hat{p}_1 }\right) + ln\left( \frac{\prod_{i=1}^{n}\hat{\lambda}_1^{x_i}e^{-\hat{\lambda}_1}}{\prod_{i=1}^{}\hat{\lambda}_0^{x_i}e^{-\hat{\lambda}_0}}\right) $$
#
#
# $$ ln\left( \frac{\hat{p}_1}{1-\hat{p}_1 }\right) + n(\hat{\lambda}_0- \hat{\lambda}_1) +  \sum_{i=1}^{n}ln(\hat{\lambda}_1-\hat{\lambda}_0)x_i $$
#
# Now we can replace $ a=  ln\left( \frac{\hat{p}_1}{1-\hat{p}_1 }\right) + n(\hat{\lambda}_0- \hat{\lambda}_1) $ and $b=ln(\hat{\lambda}_1-\hat{\lambda}_0)$ . Now following the logic of this equations we can see that if right side part of the first equation is greater than the left part (i.e. $P(y=1)P(X|Y=1)>P(y=0)P(X|Y=0$) implies that the predicted label is y=1. This is reflected in the following equation:
#
# $$ a +  \sum_{i=1}^{n}b x_i $$
#
# \begin{equation*}
#     y_{pred}=
#     \begin{cases}
#       1,& for & a +  \sum_{i=1}^{n}b x_i >0 \\
#      0,& otherwise
#     \end{cases}
# \end{equation*}

# %% [markdown]
# ### E

# %% [markdown]
# We can build the bayes optimal classifier as :
#
#
# \begin{equation*}
#     C(y_{pred},y_{true})=1-\delta=
#     \begin{cases}
#       1,& if & y_{true}!=y_{pred} \\
#      0,& otherwise
#     \end{cases}
# \end{equation*}
#
#
# Where $\delta$ is the Kronecker Delta function then if we replace in the this classifier we can see that:
# $$C_x(y_{pred},y_{true})=\sum_{y_{true}} C(y_{pred},y_{true}) P(Y=y_{true}|X) $$
# $$C_x(y_{pred},y_{true})=\sum_{y_{true}} (1-\delta) P(Y=y_{true}|X) $$
# $$C_x(y_{pred},y_{true})=\sum_{y_{true}}  P(Y=y_{true}|X)dy_{true} -\sum_{y_{true}} \delta P(Y=y_{true}|X) $$
# $$C_x(y_{pred},y_{true})=1 - P(Y=y_{pred}|X) $$
#
# Now we can see that have the same expression that know that if we maximize the probability of predict the label can be achive minimizing the loss function. Since we normally would do y=argmax $ P(Y=y_{pred}|X)$, then is the same that minimize 1- $ P(Y=y_{pred}|X)$ which is the minimization of the error of the label, which is minimize the cost function.

# %% [markdown]
# ## Part 2

# %% [markdown]
# $$ E = -\sum_{n=1}^{N}\sum_{k=1}^{K} \tau_{nk}ln\left(\frac{exp(a_k^T X_n)}{\sum_{j=1}^{K}exp(a_j^T X_n)}\right) $$
# $$ E = -\sum_{n=1}^{N}\sum_{k=1}^{K} \tau_{nk}\left[a_k^T X_n -ln\left(\sum_{j=1}^{K}exp(a_j^T X_n)\right)\right ] $$
# $$ \frac{\partial E}{\partial a_k} = \sum_{n=1}^{N} \tau_{nk}\frac{exp(a_k^T X_n)}{\sum_{j=1}^{K}exp(a_j^T X_n)}X_n -\tau_{nk}X_n +\tau_{nk!=k} \frac{exp(a_k^T X_n)}{\sum_{j=1}^{K}exp(a_j^T X_n)}X_n  $$

# %% [markdown]
# Now we can see that we have a  $\tau$ for k and another for the other values of K!=k, multipliying the $P[Y=k|X_n,a_k]$ , then this implies $\tau$ converts into a 1, then desapears. Now if we replace using this fact we get the follwing expresion. If we replace by the fact that $P[Y=k|X_n,a_k]=\frac{exp(a_k^T X_n)}{\sum_{j=1}^{K}exp(a_j^T X_n)}$ we get:

# %% [markdown]
# $$ \frac{\partial E}{\partial a_k} = \sum_{n=1}^{N} X_n \left[\frac{exp(a_k^T X_n)}{\sum_{j=1}^{K}exp(a_j^T X_n)} -\tau_{nk}\right ] $$

# %% [markdown]
# $$ \frac{\partial E}{\partial a_k} = \sum_{n=1}^{N} X_n \left[P[Y=k|X_n,a_k] -\tau_{nk}\right ] $$

# %% [markdown]
# ## Part 3

# %%
# python
import numpy as np
from sklearn . model_selection import train_test_split
from sklearn . preprocessing import StandardScaler
from sklearn . datasets import make_classification
X , y = make_classification ( n_features =2 ,n_redundant =0 ,n_informative =2 ,random_state =1 ,n_clusters_per_class =1)
rng = np . random . RandomState (2)
X += 2 * rng . uniform ( size = X . shape )
linearly_separable = (X , y )
X = StandardScaler (). fit_transform ( X )
X_train , X_test , y_train , y_test = \
train_test_split (X , y , test_size =.4 , random_state =42)

# Initialize fitting parameters
initial_theta = np . zeros (( X . shape [1] , 1))
# Set regularization parameter lambda and learning rate eta
Lambda = 0.1
Eta = 0.01

y_train = np.where(y_train == 0 , -1,1)
y_test = np.where(y_test == 0 , -1,1)

# %% [markdown]
# ### A

# %%
def lossFunction ( theta , X , y , Lambda ,index):
#
# IMPLEMENT THE LOSS AND GRADIENT FUNCTION
# OF REGULARIZED LOGISTIC REGRESSION
#
#
    loss=0
    for ind, val in enumerate(X):
        z = np.log(1 + np.exp(-y[ind] * np.dot(np.transpose(theta),X[ind]))) +  Lambda*(theta**2).sum()
        loss = loss + z[0]
    
    grad = (y[index]*X[index])

    grad2 = 1/(1+np.exp(y[index] * np.dot(np.transpose(theta),np.transpose(X[index])) ))
    
    grad3 = grad * grad2


    grad4 = grad3.reshape(theta.shape[0],1)


    return loss ,grad4

def gradientDescent(X ,y , theta , eta , Lambda , tolerance ):
#
# IMPLEMENT THE ( STOCHASTIC ) GRADIENT DESCENT ALGORITHM
# USING THE lossFunction DEFINED ABOVE
#
#
    import time

    start = time.time()
    p=X.shape[1]
    index = np.random.choice(X.shape[0], 1, replace=False) 
    i=0
    L=[0]
    theta_t_1 =  theta.copy()
    
    while True:
        theta_t = theta_t_1.reshape(p,1)*(1- 2*Lambda*eta) + eta*lossFunction(theta_t_1 , X , y , Lambda,index)[1].reshape(p,1)
        i+=1
        print("log-likehood:{}, iteration:{} ".format(lossFunction(theta_t_1 , X , y , Lambda,index )[0],i))
        L.append(lossFunction(theta_t , X , y , Lambda,index )[0])
        index = np.random.choice(X.shape[0], 1, replace=False)
        if(abs(L[len(L)-1] - L[len(L)-2])) < tolerance:
            break
        
        theta_t_1 = theta_t.copy()
  
    end = time.time()
    print("Execution time:{}".format(end - start))
    return theta_t,i,L

# %%
X_train_c = np.column_stack((X_train,np.ones([60,1])))
X_test_c = np.column_stack((X_test,np.ones([40,1])))

# %%
test = np.random.rand(2,1)

# %%
#X_train_c = np.stack(X_train,np.ones())
result_A = gradientDescent(X_train ,y_train , test,Eta , Lambda, 1e-5 )
# Out:
# log-likehood:62.789561157248954, iteration:1
# log-likehood:62.25462587789793, iteration:2
# log-likehood:62.10919687433352, iteration:3
# log-likehood:61.62909124410769, iteration:4
# log-likehood:61.35609413962714, iteration:5
# log-likehood:61.11771025588637, iteration:6
# log-likehood:61.08196542805199, iteration:7
# log-likehood:60.98831230862414, iteration:8
# log-likehood:60.773201429450346, iteration:9
# log-likehood:60.81028053678028, iteration:10
# log-likehood:60.338830052769424, iteration:11
# log-likehood:60.07327994495828, iteration:12
# log-likehood:59.26628257558831, iteration:13
# log-likehood:59.316848583359565, iteration:14
# log-likehood:59.28470549820123, iteration:15
# log-likehood:58.5786363899573, iteration:16
# log-likehood:58.63100399982826, iteration:17
# log-likehood:58.60060149455988, iteration:18
# log-likehood:58.557563718425264, iteration:19
# log-likehood:57.785506361170334, iteration:20
# log-likehood:57.03997074402783, iteration:21
# log-likehood:56.502444657500774, iteration:22
# log-likehood:56.29987132422491, iteration:23
# log-likehood:56.08194958656831, iteration:24
# log-likehood:55.856711926020814, iteration:25
# log-likehood:55.628249241623855, iteration:26
# log-likehood:55.39689813083805, iteration:27
# log-likehood:55.34958493946361, iteration:28
# log-likehood:55.316555278986534, iteration:29
# log-likehood:54.93958467932581, iteration:30
# log-likehood:54.7633296033313, iteration:31
# log-likehood:54.3768906963175, iteration:32
# log-likehood:54.16989988112588, iteration:33
# log-likehood:53.73528499876505, iteration:34
# log-likehood:53.60965540596625, iteration:35
# log-likehood:53.39220605283166, iteration:36
# log-likehood:53.318483549528516, iteration:37
# log-likehood:53.07383500939913, iteration:38
# log-likehood:52.85745197738153, iteration:39
# log-likehood:52.64781315363876, iteration:40
# log-likehood:52.439884347634354, iteration:41
# log-likehood:52.41795127227604, iteration:42
# log-likehood:52.328241055196095, iteration:43
# log-likehood:52.238889639991456, iteration:44
# log-likehood:51.590340889565944, iteration:45
# log-likehood:51.238642950855755, iteration:46
# log-likehood:51.082155842623244, iteration:47
# log-likehood:51.05045957794647, iteration:48
# log-likehood:50.86471107645995, iteration:49
# log-likehood:50.67311529072396, iteration:50
# log-likehood:50.51776170037362, iteration:51
# log-likehood:50.388523740186216, iteration:52
# log-likehood:50.229522807779304, iteration:53
# log-likehood:50.256454693442144, iteration:54
# log-likehood:50.0786767801749, iteration:55
# log-likehood:49.95630737546469, iteration:56
# log-likehood:49.78265162576735, iteration:57
# log-likehood:49.26637268098959, iteration:58
# log-likehood:48.768285317364274, iteration:59
# log-likehood:48.63362508068829, iteration:60
# log-likehood:48.610337055589895, iteration:61
# log-likehood:48.598170971323164, iteration:62
# log-likehood:48.46648289253668, iteration:63
# log-likehood:48.24099861893262, iteration:64
# log-likehood:48.052636960817225, iteration:65
# log-likehood:47.37337108916836, iteration:66
# log-likehood:47.239857802772626, iteration:67
# log-likehood:47.09938670493648, iteration:68
# log-likehood:46.96772132515376, iteration:69
# log-likehood:46.85768994760117, iteration:70
# log-likehood:46.7241953888081, iteration:71
# log-likehood:46.59693074580335, iteration:72
# log-likehood:46.16028146533223, iteration:73
# log-likehood:46.0774562836219, iteration:74
# log-likehood:45.90797183648858, iteration:75
# log-likehood:45.48732804735383, iteration:76
# log-likehood:45.55729552891485, iteration:77
# log-likehood:45.264884936434385, iteration:78
# log-likehood:45.14910096490704, iteration:79
# log-likehood:44.55426483020587, iteration:80
# log-likehood:44.5568934563965, iteration:81
# log-likehood:44.12155890278492, iteration:82
# log-likehood:44.00897400615838, iteration:83
# log-likehood:43.6331141945477, iteration:84
# log-likehood:43.68585643285195, iteration:85
# log-likehood:43.424357523098735, iteration:86
# log-likehood:43.28015068633311, iteration:87
# log-likehood:43.03471019312102, iteration:88
# log-likehood:42.51153857560808, iteration:89
# log-likehood:42.46142383245325, iteration:90
# log-likehood:42.544393860956205, iteration:91
# log-likehood:42.44353262260165, iteration:92
# log-likehood:42.34365581256135, iteration:93
# log-likehood:42.27956948506924, iteration:94
# log-likehood:42.289595910501546, iteration:95
# log-likehood:42.19685239742802, iteration:96
# log-likehood:42.080771700075964, iteration:97
# log-likehood:42.12170093002251, iteration:98
# log-likehood:42.09782504788619, iteration:99
# log-likehood:41.86005609940557, iteration:100
# log-likehood:41.78911864721864, iteration:101
# log-likehood:41.66777776116811, iteration:102
# log-likehood:41.56883159143784, iteration:103
# log-likehood:41.43983552744512, iteration:104
# log-likehood:41.312999694560126, iteration:105
# log-likehood:41.22816022970043, iteration:106
# log-likehood:40.86442138779474, iteration:107
# log-likehood:40.82093405482208, iteration:108
# log-likehood:40.71631923874118, iteration:109
# log-likehood:40.53870748219904, iteration:110
# log-likehood:40.23358958455889, iteration:111
# log-likehood:40.14608292473004, iteration:112
# log-likehood:39.94638685291472, iteration:113
# log-likehood:39.8564482582555, iteration:114
# log-likehood:39.86716470867368, iteration:115
# log-likehood:39.763732801367915, iteration:116
# log-likehood:39.46621203423352, iteration:117
# log-likehood:39.47308342457452, iteration:118
# log-likehood:39.40470426760617, iteration:119
# log-likehood:39.33172333592499, iteration:120
# log-likehood:39.31534884437978, iteration:121
# log-likehood:39.257608433045824, iteration:122
# log-likehood:38.987771999238284, iteration:123
# log-likehood:39.06298864972146, iteration:124
# log-likehood:38.9382059432513, iteration:125
# log-likehood:38.95055094299041, iteration:126
# log-likehood:38.844123055739274, iteration:127
# log-likehood:38.662491582394644, iteration:128
# log-likehood:38.58940512398776, iteration:129
# log-likehood:38.31827145792367, iteration:130
# log-likehood:38.05574835526307, iteration:131
# log-likehood:37.86790608191941, iteration:132
# log-likehood:37.81689790689793, iteration:133
# log-likehood:37.83036345525298, iteration:134
# log-likehood:37.64304840235277, iteration:135
# log-likehood:37.5631464841876, iteration:136
# log-likehood:37.501688051659826, iteration:137
# log-likehood:37.39477461986244, iteration:138
# log-likehood:37.34412847365245, iteration:139
# log-likehood:37.18541332528903, iteration:140
# log-likehood:37.122040656691006, iteration:141
# log-likehood:37.093311972715185, iteration:142
# log-likehood:37.07698060657391, iteration:143
# log-likehood:36.869158335412834, iteration:144
# log-likehood:36.70161514329367, iteration:145
# log-likehood:36.61639336610784, iteration:146
# log-likehood:36.62701461896023, iteration:147
# log-likehood:36.64458551911777, iteration:148
# log-likehood:36.581924493711874, iteration:149
# log-likehood:36.357653248055634, iteration:150
# log-likehood:36.36139917392148, iteration:151
# log-likehood:36.291956573596096, iteration:152
# log-likehood:36.249296842208906, iteration:153
# log-likehood:36.25295186226547, iteration:154
# log-likehood:36.055994202988074, iteration:155
# log-likehood:35.99749372779736, iteration:156
# log-likehood:35.95719426101765, iteration:157
# log-likehood:35.969452383142794, iteration:158
# log-likehood:35.91003536510055, iteration:159
# log-likehood:35.92590087894723, iteration:160
# log-likehood:35.88604600299342, iteration:161
# log-likehood:35.81308553968731, iteration:162
# log-likehood:35.68002864580042, iteration:163
# log-likehood:35.525817272518864, iteration:164
# log-likehood:35.459207559737166, iteration:165
# log-likehood:35.39580335724105, iteration:166
# log-likehood:35.26677880906931, iteration:167
# log-likehood:35.09713661502946, iteration:168
# log-likehood:35.149494050374024, iteration:169
# log-likehood:35.20196087902316, iteration:170
# log-likehood:35.12028077485656, iteration:171
# log-likehood:35.199770885348975, iteration:172
# log-likehood:35.216322150965894, iteration:173
# log-likehood:35.211194279164665, iteration:174
# log-likehood:35.1564841611679, iteration:175
# log-likehood:35.11478655743172, iteration:176
# log-likehood:35.041361364126175, iteration:177
# log-likehood:34.9614446795963, iteration:178
# log-likehood:34.912357724429135, iteration:179
# log-likehood:34.77168824573408, iteration:180
# log-likehood:34.84241545993237, iteration:181
# log-likehood:34.746675246885665, iteration:182
# log-likehood:34.63764162760567, iteration:183
# log-likehood:34.59732799493139, iteration:184
# log-likehood:34.46283825851895, iteration:185
# log-likehood:34.540482384895995, iteration:186
# log-likehood:34.500948474766986, iteration:187
# log-likehood:34.42433208259115, iteration:188
# log-likehood:34.382513326851665, iteration:189
# log-likehood:34.39590908847282, iteration:190
# log-likehood:34.34155060873089, iteration:191
# log-likehood:34.3927727183368, iteration:192
# log-likehood:34.40983509902696, iteration:193
# log-likehood:34.35299774991264, iteration:194
# log-likehood:34.20836111261429, iteration:195
# log-likehood:34.1532802209824, iteration:196
# log-likehood:34.101365791041324, iteration:197
# log-likehood:34.059676326935616, iteration:198
# log-likehood:34.06758706712295, iteration:199
# log-likehood:33.957259721712454, iteration:200
# log-likehood:33.83356733465533, iteration:201
# log-likehood:33.840979129174954, iteration:202
# log-likehood:33.79331256101116, iteration:203
# log-likehood:33.73949827969428, iteration:204
# log-likehood:33.636837295844224, iteration:205
# log-likehood:33.644606076163264, iteration:206
# log-likehood:33.541426696923914, iteration:207
# log-likehood:33.54971354797798, iteration:208
# log-likehood:33.49059099894532, iteration:209
# log-likehood:33.452839266250734, iteration:210
# log-likehood:33.402002414626935, iteration:211
# log-likehood:33.44365422821624, iteration:212
# log-likehood:33.395223166832594, iteration:213
# log-likehood:33.362217732819396, iteration:214
# log-likehood:33.429318220814594, iteration:215
# log-likehood:33.36714917016887, iteration:216
# log-likehood:33.27005481053299, iteration:217
# log-likehood:33.31184277133315, iteration:218
# log-likehood:33.11449358130474, iteration:219
# log-likehood:32.9052104304395, iteration:220
# log-likehood:32.816157467151726, iteration:221
# log-likehood:32.82448685584129, iteration:222
# log-likehood:32.801535744055755, iteration:223
# log-likehood:32.672712708878706, iteration:224
# log-likehood:32.73638534031813, iteration:225
# log-likehood:32.637182744175455, iteration:226
# log-likehood:32.58087625368445, iteration:227
# log-likehood:32.62770020671943, iteration:228
# log-likehood:32.61238667937796, iteration:229
# log-likehood:32.65250376988632, iteration:230
# log-likehood:32.614773423425255, iteration:231
# log-likehood:32.489286596333294, iteration:232
# log-likehood:32.435721509103466, iteration:233
# log-likehood:32.25057417004155, iteration:234
# log-likehood:32.19506710024218, iteration:235
# log-likehood:32.16988530961005, iteration:236
# log-likehood:32.13414101590662, iteration:237
# log-likehood:32.0949738543441, iteration:238
# log-likehood:32.07086784691695, iteration:239
# log-likehood:31.9963108612691, iteration:240
# log-likehood:32.01351086021845, iteration:241
# log-likehood:31.990009807559602, iteration:242
# log-likehood:32.050972205941335, iteration:243
# log-likehood:32.0179445236406, iteration:244
# log-likehood:31.997872866102, iteration:245
# log-likehood:31.971508254868635, iteration:246
# log-likehood:31.93731733377382, iteration:247
# log-likehood:31.928143324935114, iteration:248
# log-likehood:31.894409053591474, iteration:249
# log-likehood:31.904213958332424, iteration:250
# log-likehood:31.842752732488222, iteration:251
# log-likehood:31.811240953059226, iteration:252
# log-likehood:31.792397302418138, iteration:253
# log-likehood:31.756259557025245, iteration:254
# log-likehood:31.741562000247175, iteration:255
# log-likehood:31.698235540972636, iteration:256
# log-likehood:31.688689329582623, iteration:257
# log-likehood:31.666573173378023, iteration:258
# log-likehood:31.637598495658217, iteration:259
# log-likehood:31.59139117136934, iteration:260
# log-likehood:31.575100313535387, iteration:261
# log-likehood:31.558925057790688, iteration:262
# log-likehood:31.496064117573038, iteration:263
# log-likehood:31.40003725679539, iteration:264
# log-likehood:31.352619932614218, iteration:265
# log-likehood:31.312415173496763, iteration:266
# log-likehood:31.349739526817107, iteration:267
# log-likehood:31.329971684812616, iteration:268
# log-likehood:31.291820975604562, iteration:269
# log-likehood:31.264252265792564, iteration:270
# log-likehood:31.306724263174985, iteration:271
# log-likehood:31.23989429518415, iteration:272
# log-likehood:31.200583915255567, iteration:273
# log-likehood:31.108529943881397, iteration:274
# log-likehood:31.053925845525885, iteration:275
# log-likehood:31.047803456653586, iteration:276
# log-likehood:31.02449955942729, iteration:277
# log-likehood:30.89411719420602, iteration:278
# log-likehood:30.934005281856074, iteration:279
# log-likehood:30.856183457008665, iteration:280
# log-likehood:30.83261402516686, iteration:281
# log-likehood:30.81571969408731, iteration:282
# log-likehood:30.799016334607078, iteration:283
# log-likehood:30.832286994318395, iteration:284
# log-likehood:30.783487649716914, iteration:285
# log-likehood:30.74008270110205, iteration:286
# log-likehood:30.730228576088454, iteration:287
# log-likehood:30.743555944170428, iteration:288
# log-likehood:30.802193384460253, iteration:289
# log-likehood:30.778995616899266, iteration:290
# log-likehood:30.78868091686118, iteration:291
# log-likehood:30.84271570230663, iteration:292
# log-likehood:30.73599091037977, iteration:293
# log-likehood:30.70084146263658, iteration:294
# log-likehood:30.674604608083232, iteration:295
# log-likehood:30.652079480406115, iteration:296
# log-likehood:30.630575348875063, iteration:297
# log-likehood:30.5805328405065, iteration:298
# log-likehood:30.57597488433351, iteration:299
# log-likehood:30.56682243673562, iteration:300
# log-likehood:30.55082759328326, iteration:301
# log-likehood:30.560651152975936, iteration:302
# log-likehood:30.57854295760876, iteration:303
# log-likehood:30.56601678345066, iteration:304
# log-likehood:30.57678451756454, iteration:305
# log-likehood:30.56448341061013, iteration:306
# log-likehood:30.544510789828227, iteration:307
# log-likehood:30.583307733878815, iteration:308
# log-likehood:30.594853897307722, iteration:309
# log-likehood:30.582865664460297, iteration:310
# log-likehood:30.528181632636176, iteration:311
# log-likehood:30.5445480656888, iteration:312
# log-likehood:30.521885593194256, iteration:313
# log-likehood:30.501761701031835, iteration:314
# log-likehood:30.511903724423327, iteration:315
# log-likehood:30.522588969235144, iteration:316
# log-likehood:30.506135261242964, iteration:317
# log-likehood:30.544905024981244, iteration:318
# log-likehood:30.56035574481659, iteration:319
# log-likehood:30.54938706592533, iteration:320
# log-likehood:30.585615578338686, iteration:321
# log-likehood:30.622411443153045, iteration:322
# log-likehood:30.57731252959938, iteration:323
# log-likehood:30.52884146793899, iteration:324
# log-likehood:30.523855797355413, iteration:325
# log-likehood:30.514178429568467, iteration:326
# log-likehood:30.469524397005443, iteration:327
# log-likehood:30.474770316370662, iteration:328
# log-likehood:30.4657658487064, iteration:329
# log-likehood:30.445551130016465, iteration:330
# log-likehood:30.434818920352324, iteration:331
# log-likehood:30.398327679023687, iteration:332
# log-likehood:30.297619309595238, iteration:333
# log-likehood:30.308030866301785, iteration:334
# log-likehood:30.319215527778937, iteration:335
# log-likehood:30.278480221009893, iteration:336
# log-likehood:30.239660134065364, iteration:337
# log-likehood:30.23618850737252, iteration:338
# log-likehood:30.22047795660366, iteration:339
# log-likehood:30.23673815139098, iteration:340
# log-likehood:30.213651241365568, iteration:341
# log-likehood:30.101311811815957, iteration:342
# log-likehood:30.09332510106511, iteration:343
# log-likehood:30.112083301280187, iteration:344
# log-likehood:30.096066480746096, iteration:345
# log-likehood:30.08607728719143, iteration:346
# log-likehood:30.120660409262218, iteration:347
# log-likehood:30.098626464559583, iteration:348
# log-likehood:30.08299291639548, iteration:349
# log-likehood:30.088615791151458, iteration:350
# log-likehood:30.07383927432245, iteration:351
# log-likehood:30.02602746587224, iteration:352
# log-likehood:29.97300504304683, iteration:353
# log-likehood:29.931178549876137, iteration:354
# log-likehood:29.941767956551207, iteration:355
# log-likehood:29.906078586905856, iteration:356
# log-likehood:29.891680343442577, iteration:357
# log-likehood:29.872663031016817, iteration:358
# log-likehood:29.824207265225557, iteration:359
# log-likehood:29.821982519428573, iteration:360
# log-likehood:29.812867147046752, iteration:361
# log-likehood:29.80137982205489, iteration:362
# log-likehood:29.818858156165874, iteration:363
# log-likehood:29.80475852089539, iteration:364
# log-likehood:29.789808949777644, iteration:365
# log-likehood:29.758212791354936, iteration:366
# log-likehood:29.72718856507766, iteration:367
# log-likehood:29.704462829596956, iteration:368
# log-likehood:29.67576979896628, iteration:369
# log-likehood:29.607887146189704, iteration:370
# log-likehood:29.57448228506424, iteration:371
# log-likehood:29.566644231600417, iteration:372
# log-likehood:29.560057033741277, iteration:373
# log-likehood:29.54715352564915, iteration:374
# log-likehood:29.541241347904656, iteration:375
# log-likehood:29.555275694005232, iteration:376
# log-likehood:29.539482418219706, iteration:377
# log-likehood:29.532113564501095, iteration:378
# log-likehood:29.523736209563523, iteration:379
# log-likehood:29.513274206129594, iteration:380
# log-likehood:29.524115534271164, iteration:381
# log-likehood:29.497337973181544, iteration:382
# log-likehood:29.48721279761299, iteration:383
# log-likehood:29.487184504266164, iteration:384
# log-likehood:29.474985103384125, iteration:385
# log-likehood:29.468088733809964, iteration:386
# log-likehood:29.4571595382857, iteration:387
# log-likehood:29.45060576190261, iteration:388
# log-likehood:29.41029144202223, iteration:389
# log-likehood:29.385336659760707, iteration:390
# log-likehood:29.42671681315061, iteration:391
# log-likehood:29.421709553888817, iteration:392
# log-likehood:29.4000873505261, iteration:393
# log-likehood:29.430122464328345, iteration:394
# log-likehood:29.458540306867718, iteration:395
# log-likehood:29.43691550874628, iteration:396
# log-likehood:29.483372641798272, iteration:397
# log-likehood:29.46028724400544, iteration:398
# log-likehood:29.43475809553916, iteration:399
# log-likehood:29.420247610497647, iteration:400
# log-likehood:29.426395044509615, iteration:401
# log-likehood:29.419890206074438, iteration:402
# log-likehood:29.41853686750474, iteration:403
# log-likehood:29.36015271800339, iteration:404
# log-likehood:29.322484456024085, iteration:405
# log-likehood:29.317856904669128, iteration:406
# log-likehood:29.330835536027834, iteration:407
# log-likehood:29.319909451702515, iteration:408
# log-likehood:29.299881291756797, iteration:409
# log-likehood:29.28996871096397, iteration:410
# log-likehood:29.272850340402243, iteration:411
# log-likehood:29.28160630313833, iteration:412
# log-likehood:29.246570834424464, iteration:413
# log-likehood:29.236982771160047, iteration:414
# log-likehood:29.26292121074084, iteration:415
# log-likehood:29.272122897481175, iteration:416
# log-likehood:29.262589493357993, iteration:417
# log-likehood:29.25832155533169, iteration:418
# log-likehood:29.23760074052475, iteration:419
# log-likehood:29.25045901473226, iteration:420
# log-likehood:29.239509485973937, iteration:421
# log-likehood:29.23588450424884, iteration:422
# log-likehood:29.25121328769943, iteration:423
# log-likehood:29.247217903838624, iteration:424
# log-likehood:29.291015910725704, iteration:425
# log-likehood:29.286942861460552, iteration:426
# log-likehood:29.286174771700296, iteration:427
# log-likehood:29.278568294891024, iteration:428
# log-likehood:29.284451079607802, iteration:429
# log-likehood:29.275060903947093, iteration:430
# log-likehood:29.282295205737356, iteration:431
# log-likehood:29.273718080094874, iteration:432
# log-likehood:29.282887144521325, iteration:433
# log-likehood:29.29931641090433, iteration:434
# log-likehood:29.253241280841934, iteration:435
# log-likehood:29.25513559906757, iteration:436
# log-likehood:29.24951077468387, iteration:437
# log-likehood:29.24488263917506, iteration:438
# log-likehood:29.2422924100862, iteration:439
# log-likehood:29.222024269824328, iteration:440
# log-likehood:29.19051204563859, iteration:441
# log-likehood:29.20351334337404, iteration:442
# log-likehood:29.20569063717994, iteration:443
# log-likehood:29.198837715714546, iteration:444
# log-likehood:29.190207539234226, iteration:445
# log-likehood:29.14752906166066, iteration:446
# log-likehood:29.156971862245914, iteration:447
# log-likehood:29.149113753104263, iteration:448
# log-likehood:29.13941673313383, iteration:449
# log-likehood:29.136051517602734, iteration:450
# log-likehood:29.095263335437522, iteration:451
# log-likehood:29.067138351704635, iteration:452
# log-likehood:29.063296398865184, iteration:453
# log-likehood:29.054251781281835, iteration:454
# log-likehood:29.03714316158019, iteration:455
# log-likehood:29.028349006744694, iteration:456
# log-likehood:28.99155983403807, iteration:457
# log-likehood:28.984875855020356, iteration:458
# log-likehood:28.976645482099904, iteration:459
# log-likehood:28.96264327944172, iteration:460
# log-likehood:28.9543794267431, iteration:461
# log-likehood:28.9479773768229, iteration:462
# log-likehood:28.985933939479047, iteration:463
# log-likehood:28.96313570882749, iteration:464
# log-likehood:28.956512594359026, iteration:465
# log-likehood:28.953182244222695, iteration:466
# log-likehood:28.939231530288314, iteration:467
# log-likehood:28.947716769280166, iteration:468
# log-likehood:28.945121005090925, iteration:469
# log-likehood:28.95669540328888, iteration:470
# log-likehood:28.954794927418284, iteration:471
# log-likehood:28.94810547021935, iteration:472
# log-likehood:28.941594307484237, iteration:473
# log-likehood:28.95386268420247, iteration:474
# log-likehood:28.968083447161778, iteration:475
# log-likehood:28.96480503094528, iteration:476
# log-likehood:28.977272562141973, iteration:477
# log-likehood:28.934199242023404, iteration:478
# log-likehood:28.919823796981895, iteration:479
# log-likehood:28.903408943041025, iteration:480
# log-likehood:28.927655700720496, iteration:481
# log-likehood:28.965923377355857, iteration:482
# log-likehood:28.96043348428217, iteration:483
# log-likehood:28.940837502042967, iteration:484
# log-likehood:28.939564176384934, iteration:485
# log-likehood:28.964671081976036, iteration:486
# log-likehood:28.959432238116, iteration:487
# log-likehood:28.953973124864525, iteration:488
# log-likehood:28.931340532745015, iteration:489
# log-likehood:28.913929477895966, iteration:490
# log-likehood:28.901593671443923, iteration:491
# log-likehood:28.911789885866412, iteration:492
# log-likehood:28.89465775599481, iteration:493
# log-likehood:28.869242226319997, iteration:494
# log-likehood:28.846501322532077, iteration:495
# log-likehood:28.857982237567267, iteration:496
# log-likehood:28.843373288306058, iteration:497
# log-likehood:28.823595526733804, iteration:498
# log-likehood:28.81805150005754, iteration:499
# log-likehood:28.805529050607394, iteration:500
# log-likehood:28.8034092839848, iteration:501
# log-likehood:28.805575483774177, iteration:502
# log-likehood:28.79479723224032, iteration:503
# log-likehood:28.78539309546427, iteration:504
# log-likehood:28.783606300452377, iteration:505
# log-likehood:28.77168369624332, iteration:506
# log-likehood:28.793947086929425, iteration:507
# log-likehood:28.826168366411217, iteration:508
# log-likehood:28.813479673759872, iteration:509
# log-likehood:28.823500274836213, iteration:510
# log-likehood:28.810869625295002, iteration:511
# log-likehood:28.805880381175903, iteration:512
# log-likehood:28.775127084598925, iteration:513
# log-likehood:28.769672683342804, iteration:514
# log-likehood:28.765269158114045, iteration:515
# log-likehood:28.74458824556499, iteration:516
# log-likehood:28.778108482004107, iteration:517
# log-likehood:28.759456077552045, iteration:518
# log-likehood:28.731794288521566, iteration:519
# log-likehood:28.722085177634828, iteration:520
# log-likehood:28.720300261619002, iteration:521
# log-likehood:28.714192704344626, iteration:522
# log-likehood:28.735334256356825, iteration:523
# log-likehood:28.729004780968125, iteration:524
# log-likehood:28.741438808628487, iteration:525
# log-likehood:28.735434479091328, iteration:526
# log-likehood:28.735013410721926, iteration:527
# log-likehood:28.73255118932468, iteration:528
# log-likehood:28.743733746109818, iteration:529
# log-likehood:28.742497923289125, iteration:530
# log-likehood:28.737937890316946, iteration:531
# log-likehood:28.726898250026476, iteration:532
# log-likehood:28.726720129334886, iteration:533
# log-likehood:28.725563721032263, iteration:534
# log-likehood:28.73730343352383, iteration:535
# log-likehood:28.716337674131626, iteration:536
# log-likehood:28.712711045478436, iteration:537
# log-likehood:28.714899867838973, iteration:538
# log-likehood:28.709662429420646, iteration:539
# log-likehood:28.710091154847618, iteration:540
# log-likehood:28.732796844938374, iteration:541
# log-likehood:28.743441707917473, iteration:542
# log-likehood:28.739305972650975, iteration:543
# log-likehood:28.746840089711398, iteration:544
# log-likehood:28.754464533039677, iteration:545
# log-likehood:28.741835925054296, iteration:546
# log-likehood:28.739922547133077, iteration:547
# log-likehood:28.73591103991266, iteration:548
# log-likehood:28.736606058273296, iteration:549
# log-likehood:28.731064800641683, iteration:550
# log-likehood:28.70917082865713, iteration:551
# log-likehood:28.74099678484218, iteration:552
# log-likehood:28.765378798850474, iteration:553
# log-likehood:28.77608499219351, iteration:554
# log-likehood:28.74950231881002, iteration:555
# log-likehood:28.719044100804318, iteration:556
# log-likehood:28.715394892373165, iteration:557
# log-likehood:28.704621886799504, iteration:558
# log-likehood:28.73640041338621, iteration:559
# log-likehood:28.728884592073154, iteration:560
# log-likehood:28.729751419149004, iteration:561
# log-likehood:28.718071081301797, iteration:562
# log-likehood:28.709889807015163, iteration:563
# log-likehood:28.70265605415185, iteration:564
# log-likehood:28.710796141211553, iteration:565
# log-likehood:28.69897458785706, iteration:566
# log-likehood:28.698139284743405, iteration:567
# log-likehood:28.653172892011384, iteration:568
# log-likehood:28.651668949035905, iteration:569
# log-likehood:28.651542291934806, iteration:570
# log-likehood:28.650802894406233, iteration:571
# log-likehood:28.649424688908848, iteration:572
# log-likehood:28.647860778001096, iteration:573
# log-likehood:28.65562191070264, iteration:574
# log-likehood:28.613591715259556, iteration:575
# log-likehood:28.585491351032346, iteration:576
# log-likehood:28.579637628771824, iteration:577
# log-likehood:28.574886184089653, iteration:578
# log-likehood:28.571064661973356, iteration:579
# log-likehood:28.56736354856823, iteration:580
# log-likehood:28.559153382192747, iteration:581
# log-likehood:28.55616027785821, iteration:582
# log-likehood:28.56224127306495, iteration:583
# log-likehood:28.557653899694984, iteration:584
# log-likehood:28.55371724796677, iteration:585
# log-likehood:28.55251490941985, iteration:586
# log-likehood:28.56269078054745, iteration:587
# log-likehood:28.58115962750836, iteration:588
# log-likehood:28.57979480971482, iteration:589
# log-likehood:28.567640982824212, iteration:590
# log-likehood:28.574087179216814, iteration:591
# log-likehood:28.568360087610806, iteration:592
# log-likehood:28.533817837306756, iteration:593
# log-likehood:28.524711990660403, iteration:594
# log-likehood:28.516213694470434, iteration:595
# log-likehood:28.508165396765676, iteration:596
# log-likehood:28.50154367691588, iteration:597
# log-likehood:28.495078401766, iteration:598
# log-likehood:28.492936614258706, iteration:599
# log-likehood:28.50051618284183, iteration:600
# log-likehood:28.492111197008665, iteration:601
# log-likehood:28.48672100756455, iteration:602
# log-likehood:28.478965474037555, iteration:603
# log-likehood:28.49507462254711, iteration:604
# log-likehood:28.49180178959793, iteration:605
# log-likehood:28.485522557355495, iteration:606
# log-likehood:28.484366991263457, iteration:607
# log-likehood:28.474948036978965, iteration:608
# log-likehood:28.469781837548627, iteration:609
# log-likehood:28.455590474579648, iteration:610
# log-likehood:28.448796901501535, iteration:611
# log-likehood:28.455490482072754, iteration:612
# log-likehood:28.46346133851758, iteration:613
# log-likehood:28.46058082196302, iteration:614
# log-likehood:28.462488518200622, iteration:615
# log-likehood:28.487031994674524, iteration:616
# log-likehood:28.47518385252064, iteration:617
# log-likehood:28.479979730069637, iteration:618
# log-likehood:28.477758821835295, iteration:619
# log-likehood:28.47441121492711, iteration:620
# log-likehood:28.46870039549366, iteration:621
# log-likehood:28.46938028186068, iteration:622
# log-likehood:28.46194546479382, iteration:623
# log-likehood:28.456508604511445, iteration:624
# log-likehood:28.457239993174294, iteration:625
# log-likehood:28.450358195361936, iteration:626
# log-likehood:28.443620097257003, iteration:627
# log-likehood:28.43582920314456, iteration:628
# log-likehood:28.431262179480637, iteration:629
# log-likehood:28.424927480202467, iteration:630
# log-likehood:28.425682430466885, iteration:631
# log-likehood:28.42397379090781, iteration:632
# log-likehood:28.416662447363045, iteration:633
# log-likehood:28.413931163107957, iteration:634
# log-likehood:28.403270643211265, iteration:635
# log-likehood:28.396951979962605, iteration:636
# log-likehood:28.388686021711177, iteration:637
# log-likehood:28.39045066730627, iteration:638
# log-likehood:28.390324549037597, iteration:639
# log-likehood:28.388724886040524, iteration:640
# log-likehood:28.396987000578658, iteration:641
# log-likehood:28.397317905057538, iteration:642
# log-likehood:28.39760059755642, iteration:643
# log-likehood:28.395974374255108, iteration:644
# log-likehood:28.396447092783358, iteration:645
# log-likehood:28.390246477644407, iteration:646
# log-likehood:28.386757588876776, iteration:647
# log-likehood:28.374700863065883, iteration:648
# log-likehood:28.374336475736893, iteration:649
# log-likehood:28.36512461339023, iteration:650
# log-likehood:28.37898305445453, iteration:651
# log-likehood:28.386800160492825, iteration:652
# log-likehood:28.38795754771403, iteration:653
# log-likehood:28.383800334819618, iteration:654
# log-likehood:28.377288702873347, iteration:655
# log-likehood:28.382478326805263, iteration:656
# log-likehood:28.40375710544666, iteration:657
# log-likehood:28.410554487955935, iteration:658
# log-likehood:28.42700217828038, iteration:659
# log-likehood:28.432962780165926, iteration:660
# log-likehood:28.428963666752452, iteration:661
# log-likehood:28.432600938949754, iteration:662
# log-likehood:28.428554607238908, iteration:663
# log-likehood:28.424559178352418, iteration:664
# log-likehood:28.422619862247444, iteration:665
# log-likehood:28.42789784712235, iteration:666
# log-likehood:28.42095858532239, iteration:667
# log-likehood:28.410273010960832, iteration:668
# log-likehood:28.411661188606107, iteration:669
# log-likehood:28.41122837094198, iteration:670
# log-likehood:28.408088919665595, iteration:671
# log-likehood:28.408734708910895, iteration:672
# log-likehood:28.403607296346216, iteration:673
# log-likehood:28.42638361238479, iteration:674
# log-likehood:28.425036665392664, iteration:675
# log-likehood:28.42383305674667, iteration:676
# log-likehood:28.447771064464277, iteration:677
# log-likehood:28.441148928563234, iteration:678
# log-likehood:28.444336141203483, iteration:679
# log-likehood:28.440824975229322, iteration:680
# log-likehood:28.441410847601496, iteration:681
# log-likehood:28.44689047850365, iteration:682
# log-likehood:28.446510025528433, iteration:683
# log-likehood:28.43819730549538, iteration:684
# log-likehood:28.4329363009263, iteration:685
# log-likehood:28.431470786892486, iteration:686
# log-likehood:28.42594543167532, iteration:687
# log-likehood:28.429831292155146, iteration:688
# log-likehood:28.423579534560023, iteration:689
# log-likehood:28.420472338342414, iteration:690
# log-likehood:28.421078376919077, iteration:691
# log-likehood:28.44491476842302, iteration:692
# log-likehood:28.442961442975268, iteration:693
# log-likehood:28.443053073018717, iteration:694
# log-likehood:28.466826453639495, iteration:695
# log-likehood:28.466035317380456, iteration:696
# log-likehood:28.466303861311086, iteration:697
# log-likehood:28.491215417020314, iteration:698
# log-likehood:28.481468257385146, iteration:699
# log-likehood:28.481053732835484, iteration:700
# log-likehood:28.488230778939187, iteration:701
# log-likehood:28.487652336244135, iteration:702
# log-likehood:28.482372196579515, iteration:703
# log-likehood:28.477740059379673, iteration:704
# log-likehood:28.472807207688593, iteration:705
# log-likehood:28.46798261722678, iteration:706
# log-likehood:28.494150803448, iteration:707
# log-likehood:28.49188263380552, iteration:708
# log-likehood:28.491421512927225, iteration:709
# log-likehood:28.50248178649427, iteration:710
# log-likehood:28.49401234582895, iteration:711
# log-likehood:28.521415700242787, iteration:712
# log-likehood:28.520482414764434, iteration:713
# log-likehood:28.494438183472187, iteration:714
# log-likehood:28.47618401571796, iteration:715
# log-likehood:28.474815775036525, iteration:716
# log-likehood:28.48137917615239, iteration:717
# log-likehood:28.48860943164868, iteration:718
# log-likehood:28.454425235580963, iteration:719
# log-likehood:28.4457337856364, iteration:720
# log-likehood:28.447448222435145, iteration:721
# log-likehood:28.466191230125286, iteration:722
# log-likehood:28.476849230652878, iteration:723
# log-likehood:28.471839931955653, iteration:724
# log-likehood:28.47056074817815, iteration:725
# log-likehood:28.467787058687183, iteration:726
# log-likehood:28.44715679647252, iteration:727
# log-likehood:28.441402398249608, iteration:728
# log-likehood:28.450602568225836, iteration:729
# log-likehood:28.449498963083165, iteration:730
# log-likehood:28.43488638252448, iteration:731
# log-likehood:28.430163902487198, iteration:732
# log-likehood:28.41776589241968, iteration:733
# log-likehood:28.417500776807202, iteration:734
# log-likehood:28.423433820628905, iteration:735
# log-likehood:28.428724238494254, iteration:736
# log-likehood:28.446857836786744, iteration:737
# log-likehood:28.436385670835776, iteration:738
# log-likehood:28.430825274127137, iteration:739
# log-likehood:28.41853268256747, iteration:740
# log-likehood:28.410866411030202, iteration:741
# log-likehood:28.394414885647453, iteration:742
# log-likehood:28.39506644184723, iteration:743
# log-likehood:28.400732915392673, iteration:744
# log-likehood:28.399651596905542, iteration:745
# log-likehood:28.42229809919364, iteration:746
# log-likehood:28.425374160428266, iteration:747
# log-likehood:28.4271344896687, iteration:748
# log-likehood:28.422525933842515, iteration:749
# log-likehood:28.445324772742527, iteration:750
# log-likehood:28.439968277885313, iteration:751
# log-likehood:28.428391822680513, iteration:752
# log-likehood:28.427721781604752, iteration:753
# log-likehood:28.42231130705791, iteration:754
# log-likehood:28.421277333181976, iteration:755
# log-likehood:28.423076003461773, iteration:756
# log-likehood:28.424284273119003, iteration:757
# log-likehood:28.423273171765306, iteration:758
# log-likehood:28.405005084795825, iteration:759
# log-likehood:28.404055749338028, iteration:760
# log-likehood:28.397121415081653, iteration:761
# log-likehood:28.383130169498315, iteration:762
# log-likehood:28.38435920414725, iteration:763
# log-likehood:28.400899250755575, iteration:764
# log-likehood:28.402775642398048, iteration:765
# log-likehood:28.411500619560275, iteration:766
# log-likehood:28.42048926031204, iteration:767
# log-likehood:28.42682773366918, iteration:768
# log-likehood:28.42238180751579, iteration:769
# log-likehood:28.393161083089634, iteration:770
# log-likehood:28.39113069629211, iteration:771
# log-likehood:28.386482160923357, iteration:772
# log-likehood:28.394993192594008, iteration:773
# log-likehood:28.404314610524235, iteration:774
# log-likehood:28.401213176542907, iteration:775
# log-likehood:28.403324531729133, iteration:776
# log-likehood:28.403800625452273, iteration:777
# log-likehood:28.401754002156075, iteration:778
# log-likehood:28.39549569867243, iteration:779
# log-likehood:28.391976956639937, iteration:780
# log-likehood:28.396859472155924, iteration:781
# log-likehood:28.395595104191727, iteration:782
# log-likehood:28.402120952743708, iteration:783
# log-likehood:28.40009702878918, iteration:784
# log-likehood:28.4139307504951, iteration:785
# log-likehood:28.423751889742714, iteration:786
# log-likehood:28.407917121441923, iteration:787
# log-likehood:28.404769563154137, iteration:788
# log-likehood:28.40399324677364, iteration:789
# log-likehood:28.403770464554604, iteration:790
# log-likehood:28.410017597986815, iteration:791
# log-likehood:28.40539796102801, iteration:792
# log-likehood:28.408990522275634, iteration:793
# log-likehood:28.415402030387398, iteration:794
# log-likehood:28.415452355704115, iteration:795
# log-likehood:28.39748812240069, iteration:796
# log-likehood:28.39695258488327, iteration:797
# log-likehood:28.395031959182433, iteration:798
# log-likehood:28.397291242949738, iteration:799
# log-likehood:28.37840064932569, iteration:800
# log-likehood:28.374082115466084, iteration:801
# log-likehood:28.369844093980348, iteration:802
# log-likehood:28.36883314469909, iteration:803
# log-likehood:28.35935969475269, iteration:804
# log-likehood:28.360891785206384, iteration:805
# log-likehood:28.34616001744486, iteration:806
# log-likehood:28.341198562784122, iteration:807
# log-likehood:28.319735066434166, iteration:808
# log-likehood:28.31762179896282, iteration:809
# log-likehood:28.299083859108528, iteration:810
# log-likehood:28.30019362781582, iteration:811
# log-likehood:28.300701178414332, iteration:812
# log-likehood:28.2968646391606, iteration:813
# log-likehood:28.297984415881622, iteration:814
# log-likehood:28.295479104383688, iteration:815
# log-likehood:28.28458055122208, iteration:816
# log-likehood:28.288490180783167, iteration:817
# log-likehood:28.285906022631675, iteration:818
# log-likehood:28.283791691519774, iteration:819
# log-likehood:28.28351132431437, iteration:820
# log-likehood:28.289238136717145, iteration:821
# log-likehood:28.289711339263484, iteration:822
# log-likehood:28.296252493991773, iteration:823
# log-likehood:28.29304697836138, iteration:824
# log-likehood:28.29125681618034, iteration:825
# log-likehood:28.300456749732614, iteration:826
# log-likehood:28.303641051485013, iteration:827
# log-likehood:28.292519289843504, iteration:828
# log-likehood:28.292567853015253, iteration:829
# log-likehood:28.289908027281122, iteration:830
# log-likehood:28.294296502997057, iteration:831
# log-likehood:28.29486845127933, iteration:832
# log-likehood:28.29221901365523, iteration:833
# log-likehood:28.298666530507187, iteration:834
# log-likehood:28.29614469454666, iteration:835
# log-likehood:28.29383606207126, iteration:836
# log-likehood:28.293667662978077, iteration:837
# log-likehood:28.29531789988836, iteration:838
# log-likehood:28.29477031385067, iteration:839
# log-likehood:28.2923365483762, iteration:840
# log-likehood:28.29027707663968, iteration:841
# log-likehood:28.281567966407405, iteration:842
# log-likehood:28.282819831739516, iteration:843
# log-likehood:28.28235420079603, iteration:844
# log-likehood:28.279519614475202, iteration:845
# log-likehood:28.290908254745315, iteration:846
# log-likehood:28.28738049735021, iteration:847
# log-likehood:28.293983612183776, iteration:848
# log-likehood:28.290123090455868, iteration:849
# log-likehood:28.293426928029064, iteration:850
# log-likehood:28.29122246116287, iteration:851
# log-likehood:28.29192351503039, iteration:852
# log-likehood:28.292536028417285, iteration:853
# log-likehood:28.30166025992411, iteration:854
# log-likehood:28.299480064080655, iteration:855
# log-likehood:28.299262745292708, iteration:856
# log-likehood:28.30200401542717, iteration:857
# log-likehood:28.30230770460576, iteration:858
# log-likehood:28.29680005078828, iteration:859
# log-likehood:28.29313398088284, iteration:860
# log-likehood:28.295799885019402, iteration:861
# log-likehood:28.302861255579323, iteration:862
# log-likehood:28.293150424399723, iteration:863
# log-likehood:28.29963179222756, iteration:864
# log-likehood:28.309038189679832, iteration:865
# log-likehood:28.309352202132853, iteration:866
# log-likehood:28.297522830312, iteration:867
# log-likehood:28.291754327159747, iteration:868
# log-likehood:28.29166430741318, iteration:869
# log-likehood:28.298028660664436, iteration:870
# log-likehood:28.301456415701157, iteration:871
# log-likehood:28.301379318394034, iteration:872
# log-likehood:28.30147121960801, iteration:873
# log-likehood:28.298451386112216, iteration:874
# log-likehood:28.296518076003537, iteration:875
# log-likehood:28.29084491519, iteration:876
# log-likehood:28.285532928922315, iteration:877
# log-likehood:28.28614657234201, iteration:878
# log-likehood:28.300617840932762, iteration:879
# log-likehood:28.298067939304527, iteration:880
# log-likehood:28.304879373436204, iteration:881
# log-likehood:28.296190579866806, iteration:882
# log-likehood:28.28709258005516, iteration:883
# log-likehood:28.289549543599545, iteration:884
# log-likehood:28.281907953723493, iteration:885
# log-likehood:28.27284405614613, iteration:886
# log-likehood:28.269474109263037, iteration:887
# log-likehood:28.270452026547296, iteration:888
# log-likehood:28.269027213263602, iteration:889
# log-likehood:28.27040919529957, iteration:890
# log-likehood:28.273327058284615, iteration:891
# log-likehood:28.26472920315937, iteration:892
# log-likehood:28.25902786662803, iteration:893
# log-likehood:28.263829816366695, iteration:894
# log-likehood:28.26389916917171, iteration:895
# log-likehood:28.262134699449465, iteration:896
# log-likehood:28.260309361370613, iteration:897
# log-likehood:28.259503116533413, iteration:898
# log-likehood:28.25505132667943, iteration:899
# log-likehood:28.259780781823274, iteration:900
# log-likehood:28.258166468108602, iteration:901
# log-likehood:28.256424615761922, iteration:902
# log-likehood:28.26813707586798, iteration:903
# log-likehood:28.266756290444686, iteration:904
# log-likehood:28.262977802111344, iteration:905
# log-likehood:28.26211822194385, iteration:906
# log-likehood:28.259188641951692, iteration:907
# log-likehood:28.25801571713144, iteration:908
# log-likehood:28.25903721487277, iteration:909
# log-likehood:28.254668506003686, iteration:910
# log-likehood:28.25161872269074, iteration:911
# log-likehood:28.255529623438978, iteration:912
# log-likehood:28.25625080527087, iteration:913
# log-likehood:28.265163563097765, iteration:914
# log-likehood:28.263846586593214, iteration:915
# log-likehood:28.25734574367325, iteration:916
# log-likehood:28.26640468003636, iteration:917
# log-likehood:28.266190404058516, iteration:918
# log-likehood:28.278594095630822, iteration:919
# log-likehood:28.289762176944592, iteration:920
# log-likehood:28.281181496833092, iteration:921
# log-likehood:28.281247882315977, iteration:922
# log-likehood:28.28491465453546, iteration:923
# log-likehood:28.283255201516244, iteration:924
# log-likehood:28.27518452235427, iteration:925
# log-likehood:28.27499313748673, iteration:926
# log-likehood:28.26831182699779, iteration:927
# log-likehood:28.270795013461093, iteration:928
# log-likehood:28.272901419882903, iteration:929
# log-likehood:28.270938536591206, iteration:930
# log-likehood:28.269504854918193, iteration:931
# log-likehood:28.267677952646245, iteration:932
# log-likehood:28.26482111473242, iteration:933
# log-likehood:28.267295764053916, iteration:934
# log-likehood:28.26566808182917, iteration:935
# log-likehood:28.26774000559496, iteration:936
# log-likehood:28.271049615679708, iteration:937
# log-likehood:28.26256724566454, iteration:938
# log-likehood:28.26061773559728, iteration:939
# log-likehood:28.25894134598858, iteration:940
# log-likehood:28.257293188821574, iteration:941
# log-likehood:28.25537767243968, iteration:942
# log-likehood:28.248367507868714, iteration:943
# log-likehood:28.24935499358955, iteration:944
# log-likehood:28.249210787643328, iteration:945
# log-likehood:28.246225401694364, iteration:946
# log-likehood:28.244960981904015, iteration:947
# log-likehood:28.243780143707717, iteration:948
# log-likehood:28.244077651175772, iteration:949
# log-likehood:28.240611663065277, iteration:950
# log-likehood:28.235701679923444, iteration:951
# log-likehood:28.23684723530927, iteration:952
# log-likehood:28.238351697752822, iteration:953
# log-likehood:28.2378102328529, iteration:954
# log-likehood:28.233651407147132, iteration:955
# log-likehood:28.232678406969686, iteration:956
# log-likehood:28.233796732756407, iteration:957
# log-likehood:28.236156385125263, iteration:958
# log-likehood:28.236235733064014, iteration:959
# log-likehood:28.235226886747895, iteration:960
# log-likehood:28.23733226727336, iteration:961
# log-likehood:28.237703763271735, iteration:962
# log-likehood:28.237612357620367, iteration:963
# log-likehood:28.24293789512481, iteration:964
# log-likehood:28.239836453547607, iteration:965
# log-likehood:28.23487128203325, iteration:966
# log-likehood:28.233484402049548, iteration:967
# log-likehood:28.232575306950164, iteration:968
# log-likehood:28.228779901743675, iteration:969
# log-likehood:28.225479311794636, iteration:970
# log-likehood:28.224057443768114, iteration:971
# log-likehood:28.22404565553099, iteration:972
# log-likehood:28.224191304486606, iteration:973
# log-likehood:28.22415955112107, iteration:974
# log-likehood:28.224387672136054, iteration:975
# log-likehood:28.223359084845438, iteration:976
# log-likehood:28.224953859909643, iteration:977
# log-likehood:28.225117076921855, iteration:978
# log-likehood:28.231083343762954, iteration:979
# log-likehood:28.234036528670412, iteration:980
# log-likehood:28.234101776147472, iteration:981
# log-likehood:28.231488734418267, iteration:982
# log-likehood:28.233336540584983, iteration:983
# log-likehood:28.236642636516514, iteration:984
# log-likehood:28.243254574306945, iteration:985
# log-likehood:28.242963958129955, iteration:986
# log-likehood:28.24313048245192, iteration:987
# log-likehood:28.245910696458967, iteration:988
# log-likehood:28.248702622220062, iteration:989
# log-likehood:28.255015751720542, iteration:990
# log-likehood:28.25353650765071, iteration:991
# log-likehood:28.25369232763971, iteration:992
# log-likehood:28.255985932876687, iteration:993
# log-likehood:28.254507280842667, iteration:994
# log-likehood:28.25579842843062, iteration:995
# log-likehood:28.257175026241182, iteration:996
# log-likehood:28.255694782927897, iteration:997
# log-likehood:28.253948162149833, iteration:998
# log-likehood:28.252044972935792, iteration:999
# log-likehood:28.251984522068383, iteration:1000
# log-likehood:28.248336615076322, iteration:1001
# log-likehood:28.242038567103982, iteration:1002
# log-likehood:28.245893176747966, iteration:1003
# log-likehood:28.242380457691578, iteration:1004
# log-likehood:28.24811871646542, iteration:1005
# log-likehood:28.251221051924784, iteration:1006
# log-likehood:28.250947454889996, iteration:1007
# log-likehood:28.248977265103267, iteration:1008
# log-likehood:28.24507054486147, iteration:1009
# log-likehood:28.240698363493216, iteration:1010
# log-likehood:28.24103666415335, iteration:1011
# log-likehood:28.237808651894678, iteration:1012
# log-likehood:28.237707277568575, iteration:1013
# log-likehood:28.238076159556343, iteration:1014
# log-likehood:28.238221962133032, iteration:1015
# log-likehood:28.243609112159607, iteration:1016
# log-likehood:28.235496359656867, iteration:1017
# log-likehood:28.236912831843778, iteration:1018
# log-likehood:28.238166012531163, iteration:1019
# log-likehood:28.247212867507006, iteration:1020
# log-likehood:28.242626266363377, iteration:1021
# log-likehood:28.251947604933566, iteration:1022
# log-likehood:28.24937237598814, iteration:1023
# log-likehood:28.244123235509978, iteration:1024
# log-likehood:28.24289142703137, iteration:1025
# log-likehood:28.241668930902094, iteration:1026
# log-likehood:28.2419022201086, iteration:1027
# log-likehood:28.24469228989016, iteration:1028
# log-likehood:28.252242803087587, iteration:1029
# log-likehood:28.250785195343834, iteration:1030
# log-likehood:28.261744024472655, iteration:1031
# log-likehood:28.264019098124955, iteration:1032
# log-likehood:28.26445831537939, iteration:1033
# log-likehood:28.262679628066028, iteration:1034
# log-likehood:28.259675727303968, iteration:1035
# log-likehood:28.261954467166504, iteration:1036
# log-likehood:28.274384094952687, iteration:1037
# log-likehood:28.27447842092035, iteration:1038
# log-likehood:28.27012837319747, iteration:1039
# log-likehood:28.280515207323937, iteration:1040
# log-likehood:28.283665544608684, iteration:1041
# log-likehood:28.283495483472084, iteration:1042
# log-likehood:28.287708795757514, iteration:1043
# log-likehood:28.281688735771798, iteration:1044
# log-likehood:28.287701633605, iteration:1045
# log-likehood:28.28163759751905, iteration:1046
# log-likehood:28.2795759621454, iteration:1047
# log-likehood:28.279338704092883, iteration:1048
# log-likehood:28.276124120209996, iteration:1049
# log-likehood:28.276241654426943, iteration:1050
# log-likehood:28.276105319958123, iteration:1051
# log-likehood:28.274304658527956, iteration:1052
# log-likehood:28.274197128541854, iteration:1053
# log-likehood:28.287998121415693, iteration:1054
# log-likehood:28.289309912809575, iteration:1055
# log-likehood:28.304584837428642, iteration:1056
# log-likehood:28.302170143746583, iteration:1057
# log-likehood:28.301871239892648, iteration:1058
# log-likehood:28.31824525107901, iteration:1059
# log-likehood:28.3188731834821, iteration:1060
# log-likehood:28.316687937998882, iteration:1061
# log-likehood:28.31694026185755, iteration:1062
# log-likehood:28.303959403789136, iteration:1063
# log-likehood:28.310997676409496, iteration:1064
# log-likehood:28.31084187666492, iteration:1065
# log-likehood:28.315180234301206, iteration:1066
# log-likehood:28.315232063701327, iteration:1067
# log-likehood:28.31201488347697, iteration:1068
# log-likehood:28.319368501775127, iteration:1069
# log-likehood:28.311811081816522, iteration:1070
# log-likehood:28.31208311942647, iteration:1071
# log-likehood:28.30974873195105, iteration:1072
# log-likehood:28.309590080341177, iteration:1073
# log-likehood:28.31435487027658, iteration:1074
# log-likehood:28.311305896636977, iteration:1075
# log-likehood:28.310730599348076, iteration:1076
# log-likehood:28.318522665008906, iteration:1077
# log-likehood:28.315639620172036, iteration:1078
# log-likehood:28.313256347788702, iteration:1079
# log-likehood:28.312997663432988, iteration:1080
# log-likehood:28.320901119665283, iteration:1081
# log-likehood:28.328907484257318, iteration:1082
# log-likehood:28.34728522193945, iteration:1083
# log-likehood:28.351461845812796, iteration:1084
# log-likehood:28.34647961518882, iteration:1085
# log-likehood:28.355512839301262, iteration:1086
# log-likehood:28.352966262046344, iteration:1087
# log-likehood:28.349487503125157, iteration:1088
# log-likehood:28.3584105195496, iteration:1089
# log-likehood:28.36280642835057, iteration:1090
# log-likehood:28.363135363063687, iteration:1091
# log-likehood:28.363012853661818, iteration:1092
# log-likehood:28.353494168882985, iteration:1093
# log-likehood:28.35336627935628, iteration:1094
# log-likehood:28.353089994874043, iteration:1095
# log-likehood:28.35508097673878, iteration:1096
# log-likehood:28.36016226553874, iteration:1097
# log-likehood:28.363789913029105, iteration:1098
# log-likehood:28.365734384634884, iteration:1099
# log-likehood:28.366136355231713, iteration:1100
# log-likehood:28.386752330612268, iteration:1101
# log-likehood:28.396526042429887, iteration:1102
# log-likehood:28.399285715754882, iteration:1103
# log-likehood:28.41780855169541, iteration:1104
# log-likehood:28.417630952293813, iteration:1105
# log-likehood:28.41078571760932, iteration:1106
# log-likehood:28.433237432595252, iteration:1107
# log-likehood:28.447224866697105, iteration:1108
# log-likehood:28.42960425979827, iteration:1109
# log-likehood:28.425122420369306, iteration:1110
# log-likehood:28.43162625418898, iteration:1111
# log-likehood:28.43895139616271, iteration:1112
# log-likehood:28.4432673697514, iteration:1113
# log-likehood:28.454321189395657, iteration:1114
# log-likehood:28.446642981672138, iteration:1115
# log-likehood:28.457778085188526, iteration:1116
# log-likehood:28.449729336111567, iteration:1117
# log-likehood:28.437348691583484, iteration:1118
# log-likehood:28.43275255462591, iteration:1119
# log-likehood:28.432903655900045, iteration:1120
# log-likehood:28.421072013057344, iteration:1121
# log-likehood:28.440465871553208, iteration:1122
# log-likehood:28.43582856761026, iteration:1123
# log-likehood:28.415577570066908, iteration:1124
# log-likehood:28.421910632973063, iteration:1125
# log-likehood:28.417356361663057, iteration:1126
# log-likehood:28.417283499837353, iteration:1127
# log-likehood:28.41846301425449, iteration:1128
# log-likehood:28.397768654642068, iteration:1129
# log-likehood:28.4078363279734, iteration:1130
# log-likehood:28.412573992125864, iteration:1131
# log-likehood:28.422983617404896, iteration:1132
# log-likehood:28.406498748441408, iteration:1133
# log-likehood:28.397498199601593, iteration:1134
# log-likehood:28.39337028195435, iteration:1135
# log-likehood:28.40294420365697, iteration:1136
# log-likehood:28.405249721355343, iteration:1137
# log-likehood:28.400078448925257, iteration:1138
# log-likehood:28.40128437988096, iteration:1139
# log-likehood:28.394831789109126, iteration:1140
# log-likehood:28.389119695437728, iteration:1141
# log-likehood:28.361278834590223, iteration:1142
# log-likehood:28.356925711163438, iteration:1143
# log-likehood:28.351994493403563, iteration:1144
# log-likehood:28.352485438972273, iteration:1145
# log-likehood:28.35000223457141, iteration:1146
# log-likehood:28.334205773690467, iteration:1147
# log-likehood:28.331053634574236, iteration:1148
# log-likehood:28.349264003261503, iteration:1149
# log-likehood:28.358095400347764, iteration:1150
# log-likehood:28.344924914941092, iteration:1151
# log-likehood:28.34474966738776, iteration:1152
# log-likehood:28.342167682844252, iteration:1153
# log-likehood:28.34165725609379, iteration:1154
# log-likehood:28.352503996883204, iteration:1155
# log-likehood:28.361426285581043, iteration:1156
# log-likehood:28.361246942075574, iteration:1157
# log-likehood:28.361079844054345, iteration:1158
# log-likehood:28.361579027470942, iteration:1159
# log-likehood:28.362449327347047, iteration:1160
# log-likehood:28.35885991487825, iteration:1161
# log-likehood:28.36090227688199, iteration:1162
# log-likehood:28.36077387524232, iteration:1163
# log-likehood:28.3562541884019, iteration:1164
# log-likehood:28.365318078263275, iteration:1165
# log-likehood:28.365423885768116, iteration:1166
# log-likehood:28.355948712961936, iteration:1167
# log-likehood:28.350625238194777, iteration:1168
# log-likehood:28.359548227392168, iteration:1169
# log-likehood:28.3684346714888, iteration:1170
# log-likehood:28.37324650837848, iteration:1171
# log-likehood:28.372694767898203, iteration:1172
# log-likehood:28.372795524517556, iteration:1173
# log-likehood:28.37768634608008, iteration:1174
# log-likehood:28.377848666270985, iteration:1175
# log-likehood:28.368014367182834, iteration:1176
# log-likehood:28.36250291683093, iteration:1177
# log-likehood:28.337420969675335, iteration:1178
# log-likehood:28.343403111246623, iteration:1179
# log-likehood:28.34610141757847, iteration:1180
# log-likehood:28.35227669395587, iteration:1181
# log-likehood:28.34962237499279, iteration:1182
# log-likehood:28.350955172060537, iteration:1183
# log-likehood:28.3421613030468, iteration:1184
# log-likehood:28.342150059602503, iteration:1185
# log-likehood:28.336746340511183, iteration:1186
# log-likehood:28.33248462125712, iteration:1187
# log-likehood:28.33697270822535, iteration:1188
# log-likehood:28.337235568835283, iteration:1189
# log-likehood:28.334820515823022, iteration:1190
# log-likehood:28.3348451467443, iteration:1191
# log-likehood:28.331625582847416, iteration:1192
# log-likehood:28.34027314557973, iteration:1193
# log-likehood:28.328094368670545, iteration:1194
# log-likehood:28.325816739568893, iteration:1195
# log-likehood:28.325968524937196, iteration:1196
# log-likehood:28.31821123703016, iteration:1197
# log-likehood:28.318933168567224, iteration:1198
# log-likehood:28.316204133986037, iteration:1199
# log-likehood:28.318727011834348, iteration:1200
# log-likehood:28.318792198224386, iteration:1201
# log-likehood:28.322169719393003, iteration:1202
# log-likehood:28.325480817856466, iteration:1203
# log-likehood:28.340489472913376, iteration:1204
# log-likehood:28.340852707474966, iteration:1205
# log-likehood:28.33253410197229, iteration:1206
# log-likehood:28.335213286431088, iteration:1207
# log-likehood:28.352725921321476, iteration:1208
# log-likehood:28.359088517625274, iteration:1209
# log-likehood:28.360526517514035, iteration:1210
# Execution time:4.257124185562134

# %%
test
# Out:
# array([[0.40151728],
#        [0.67787076]])

# %%
result_A[0]
# Out:
# array([[-1.01762841],
#        [ 0.13941332]])

# %% [markdown]
# ### B

# %%
import matplotlib.pyplot as plt
plt.plot(result_A[2][1:],color='r', label='error square')
plt.xlabel('Iterations')
plt.ylabel("-Log()")
# Out:
# Text(0, 0.5, '-Log()')

# %% [markdown]
# ### C

# %%
y_hat_test = 1/(1+np.exp(-X_test@result_A[0]))
y_hat_train = 1/(1+np.exp(-X_train@result_A[0]))
y_predict_test = np.where(y_hat_test>.5,1,-1)
y_predict_train = np.where(y_hat_train>.5,1,-1)
acc_test = 0
acc_train = 0
for i, val in  enumerate(y_train):
    if y_train[i] == y_predict_train[i]  :
        acc_train= acc_train+ 1


for i, val in  enumerate(y_test):
    if y_test[i] == y_predict_test[i] :
        acc_test=acc_test+1
        
        
acc_test = acc_test/len(y_test) 
acc_train = acc_train/len(y_train)  

#acc_test = acc_test
#acc_train = acc_train



print("Training Accuracy:{}".format(acc_train))
print("Test Accuracy:{}".format(acc_test))
# Out:
# Training Accuracy:0.9666666666666667
# Test Accuracy:0.95

# %%
from matplotlib.colors import ListedColormap


xx1_test = np.linspace( X_test [: , 0].min(), X_test [: , 0].max(),40)
bound_test = - xx1_test *result_A[0][0][0]/result_A[0][1][0]  #result_A[0][2][0]/result_A[0][1][0]*0

xx1_train = np.linspace( X_train [: , 0].min(), X_train [: , 0].max(),40)
bound_train = - xx1_train *result_A[0][0][0]/result_A[0][1][0] #result_A[0][2][0]/result_A[0][1][0]*0

x_min , x_max = X [: , 0]. min () - .5 , X [: , 0]. max () + .5
y_min , y_max = X [: , 1]. min () - .5 , X [: , 1]. max () + .5
h = .02 # step size in the mesh
xx , yy = np . meshgrid ( np . arange ( x_min , x_max , h ) ,
np . arange ( y_min , y_max , h ))
# plot the dataset
cm = plt . cm . RdBu
cm_bright = ListedColormap (['#FF0000','#0000FF'])
# Plot the training points
plt . scatter ( X_train [: , 0] , X_train [: , 1] , c = y_train ,
cmap = cm_bright , edgecolors ='k')
plt.plot(xx1_train,bound_train)

# %%
# and test points
plt . scatter ( X_test [: , 0] , X_test [: , 1] , c = y_test ,
cmap = cm_bright , alpha =0.6 , edgecolors ='k')
#plt.plot( X_test [: , 0],bound)
plt.plot(xx1_test,bound_test)
